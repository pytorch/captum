# %% [markdown]
# # Visualizing features with captum.optim
#
# This notebook demonstrates the use of the `captum.optim` submodule for visualizing features for a MobileNetV2 model imported from `torchvision`. The `optim` submodule shows the increasing complexity of the features learned as we go deeper into the model. We also briefly touch on the `ImageTensor` class for easily loading and visualizing tensors that are also images.

# %%
# %load_ext autoreload
# %autoreload 2

import torch
import torchvision
from torchvision.models import alexnet

import captum.optim as optimviz

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## ImageTensor
#
# The `ImageTensor` class is a wrapper around `torch.Tensor` that allows for easy loading and viewing of images.

# %%
# Use ImageTensor.open() with a URL or filepath to load an image
t = optimviz.ImageTensor.open(
    "https://raw.githubusercontent.com/pytorch/captum/master/website/static/img/captum_logo.png"
)
# Use show() to quickly view the image.
t.show()

# %% [markdown]
# ## InputOptimization
#
# `InputOptimization` is the core function for visualizing features with `captum.optim`.
#
# It takes five arguments:
# - The model whose feature(s) we are visualizing
# - A torch.nn.Module object that generates inputs to the model (e.g. NaturalImage)
# - A transformation or series of transformations preprocessing the input before passing to the model
# - A loss function based on target layers from the model

# %%
# Load the model
model = alexnet(pretrained=True).to(device)

# Initialize an input - NaturalImage uses FFT parameterization and color decorrelation
image = optimviz.images.NaturalImage((224, 224)).to(device) # This creates a Module that returns an ImageTensor

# Initialize a series of transformations
transforms = torch.nn.Sequential(
    # Normalization for torchvision models
    torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    # Random translation, scaling, and rotation to help with visualization quality.
    # Padding is used to avoid transform artifacts and then it's cropped away.
    torch.nn.ReflectionPad2d(16),
    optimviz.transform.RandomSpatialJitter(16),
    optimviz.transform.RandomScale(scale=(1, 0.975, 1.025, 0.95, 1.05)),
    torchvision.transforms.RandomRotation(degrees=(-5,5)),
    optimviz.transform.RandomSpatialJitter(8),
    optimviz.transform.CenterCrop(16),
)

# Create a loss function based on the target layer
loss_fn = optimviz.loss.ChannelActivation(model.features[1], 5)

# Initialize InputOptimization and run optimize
obj = optimviz.InputOptimization(model, image, transforms, loss_fn)
history = obj.optimize(optimviz.objectives.n_steps(128))

image().show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))

# %% [markdown]
# For convenience, we can create a helper function for visualizing different layers in our model.

# %%
def visualize(model, target, channel=-1, lr=0.025):
    image = optimviz.images.NaturalImage((224, 224)).to(device)
    transforms = torch.nn.Sequential(
        torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        torch.nn.ReflectionPad2d(16),
        optimviz.transform.RandomSpatialJitter(16),
        optimviz.transform.RandomScale(scale=(1, 0.975, 1.025, 0.95, 1.05)),
        torchvision.transforms.RandomRotation(degrees=(-5,5)),
        optimviz.transform.RandomSpatialJitter(8),
        optimviz.transform.CenterCrop(16),
    )
    if channel > -1:
        loss_fn = optimviz.loss.ChannelActivation(target, channel)
    else:
        loss_fn = optimviz.loss.DeepDream(target)
    obj = optimviz.InputOptimization(model, image, transforms, loss_fn, lr=lr)
    history = obj.optimize(optimviz.objectives.n_steps(128))
    print(image().shape)
    image().show()

# %% [markdown]
# With visualization, we can see that deeper features detect for increasingly complex elements.

# %%
visualize(model, model.features[4], 18)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))
# torch.Size([1, 3, 224, 224])

# %%
visualize(model, model.features[1], 5)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))
# torch.Size([1, 3, 223, 223])

# %%
for i in range(10, 20):
    visualize(model, model.features[4], i)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-203-02a633565720> in <module>
#       1 for i in range(10, 20):
# ----> 2     visualize(model, model.features[4], i)
#
# <ipython-input-146-faa64e770aa7> in visualize(model, target, channel, lr)
#      15         loss_fn = optimviz.loss.DeepDream(target)
#      16     obj = optimviz.InputOptimization(model, image, transforms, loss_fn, lr=lr)
# ---> 17     history = obj.optimize(optimviz.objectives.n_steps(128))
#      18     image().show()
#
# ~/Desktop/captum/captum/optim/_core/objectives.py in optimize(self, stop_criteria, optimizer)
#     140         except (Exception, BaseException) as e:
#     141             self.cleanup()
# --> 142             raise e
#     143         self.cleanup()
#     144         return history
#
# ~/Desktop/captum/captum/optim/_core/objectives.py in optimize(self, stop_criteria, optimizer)
#     135                 loss_value = self.loss()
#     136                 history.append(loss_value.cpu().detach().numpy())
# --> 137                 (-1 * loss_value.mean()).backward()
#     138                 optimizer.step()
#     139                 step += 1
#
# /usr/local/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# /usr/local/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# /usr/local/lib/python3.8/site-packages/torch/autograd/function.py in apply(self, *args)
#      85     _is_legacy = False
#      86
# ---> 87     def apply(self, *args):
#      88         # _forward_cls is defined by derived class
#      89         return self._forward_cls.backward(self, *args)  # type: ignore
#
# KeyboardInterrupt:

# %%
visualize(model, model.features[9], 8)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))

# %%
import captum.optim._utils.models
optimviz._utils.models.replace_layers(model, old_layer=torch.nn.ReLU)

# %%
visualize(model, model.features[9], 8)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))

# %%
visualize(model, model.features[9], 8)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))

# %%
visualize(model, model.features[11], 14)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))

# %% [markdown]
# We can also visualize different classes in the final layer and see how they are similar to their corresponding ImageNet labels.

# %%
visualize(model, model.classifier[6], 9) # Ostrich
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))

# %%
visualize(model, model.classifier[6], 319) # Dragonfly
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))

# %%
visualize(model, model.classifier[6], 949) # Toilet paper
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))

# %%
visualize(model, model.classifier[6], 949) # Toilet paper
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-199-138455ffc4d7> in <module>
# ----> 1 visualize(model, model.classifier[6], 949) # Toilet paper
#
# <ipython-input-146-faa64e770aa7> in visualize(model, target, channel, lr)
#      15         loss_fn = optimviz.loss.DeepDream(target)
#      16     obj = optimviz.InputOptimization(model, image, transforms, loss_fn, lr=lr)
# ---> 17     history = obj.optimize(optimviz.objectives.n_steps(128))
#      18     image().show()
#
# ~/Desktop/captum/captum/optim/_core/objectives.py in optimize(self, stop_criteria, optimizer)
#     140         except (Exception, BaseException) as e:
#     141             self.cleanup()
# --> 142             raise e
#     143         self.cleanup()
#     144         return history
#
# ~/Desktop/captum/captum/optim/_core/objectives.py in optimize(self, stop_criteria, optimizer)
#     131         step = 0
#     132         try:
# --> 133             while stop_criteria(step, self, history, optimizer):
#     134                 optimizer.zero_grad()
#     135                 loss_value = self.loss()
#
# ~/Desktop/captum/captum/optim/_core/objectives.py in continue_while(step, obj, history, optim)
#     161             return True
#     162         else:
# --> 163             pbar.close()
#     164             return False
#     165
#
# /usr/local/lib/python3.8/site-packages/tqdm/notebook.py in close(self, *args, **kwargs)
#     249
#     250     def close(self, *args, **kwargs):
# --> 251         super(tqdm_notebook, self).close(*args, **kwargs)
#     252         # Try to detect if there was an error or KeyboardInterrupt
#     253         # in manual mode: if n < total, things probably got wrong
#
# /usr/local/lib/python3.8/site-packages/tqdm/std.py in close(self)
#    1269         # decrement instance pos and remove from internal set
#    1270         pos = abs(self.pos)
# -> 1271         self._decr_instances(self)
#    1272
#    1273         # GUI mode
#
# /usr/local/lib/python3.8/site-packages/tqdm/std.py in _decr_instances(cls, instance)
#     570             if not cls._instances and cls.monitor:
#     571                 try:
# --> 572                     cls.monitor.exit()
#     573                     del cls.monitor
#     574                 except AttributeError:  # pragma: nocover
#
# /usr/local/lib/python3.8/site-packages/tqdm/_monitor.py in exit(self)
#      51         self.was_killed.set()
#      52         if self is not current_thread():
# ---> 53             self.join()
#      54         return self.report()
#      55
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/threading.py in join(self, timeout)
#    1009
#    1010         if timeout is None:
# -> 1011             self._wait_for_tstate_lock()
#    1012         else:
#    1013             # the behavior of a negative timeout isn't documented, but
#
# /usr/local/Cellar/python@3.8/3.8.5/Frameworks/Python.framework/Versions/3.8/lib/python3.8/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1025         if lock is None:  # already determined that the C code is done
#    1026             assert self._is_stopped
# -> 1027         elif lock.acquire(block, timeout):
#    1028             lock.release()
#    1029             self._stop()
#
# KeyboardInterrupt:

# %%
from torchvision.models import vgg16 # Torchvision's VGG-16 model
model = vgg16(pretrained=True).to(device)
visualize(model, model.features[26], 50) # Optimize without RedirectedReLU
# Out:
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))

# %%
#import captum.optim._utils.models

model = vgg16(pretrained=True).to(device)

# Replace ReLU layers with RedirectedReLU to enhance quality
optimviz._utils.models.replace_layers(model, old_layer=torch.nn.ReLU)

visualize(model, model.features[26], 50) # Optimize without RedirectedReLU
# Out:
# HBox(children=(FloatProgress(value=0.0, max=16.0), HTML(value='')))
